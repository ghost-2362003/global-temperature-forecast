# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv("globalWarming.csv")
data
# Out:
#      Unnamed: 0  date  LandAverageTemperature  \
# 0             0  1850                7.900667
# 1             1  1851                8.178583
# 2             2  1852                8.100167
# 3             3  1853                8.041833
# 4             4  1854                8.210500
# ..          ...   ...                     ...
# 161         161  2011                9.516000
# 162         162  2012                9.507333
# 163         163  2013                9.606500
# 164         164  2014                9.570667
# 165         165  2015                9.831000
#
#      LandAverageTemperatureUncertainty  LandMaxTemperature  \
# 0                             0.876417           13.476667
# 1                             0.881917           13.081000
# 2                             0.918250           13.397333
# 3                             0.835000           13.886583
# 4                             0.825667           13.977417
# ..                                 ...                 ...
# 161                           0.082000           15.284833
# 162                           0.083417           15.332833
# 163                           0.097667           15.373833
# 164                           0.090167           15.313583
# 165                           0.092167           15.572667
#
#      LandMaxTemperatureUncertainty  LandMinTemperature  \
# 0                         2.394833            1.964333
# 1                         2.397250            2.203917
# 2                         2.619250            2.337000
# 3                         2.095083            1.892500
# 4                         1.783333            1.762167
# ..                             ...                 ...
# 161                       0.114333            3.827667
# 162                       0.107333            3.756167
# 163                       0.115500            3.911333
# 164                       0.111667            3.877750
# 165                       0.106500            4.148833
#
#      LandMinTemperatureUncertainty  LandAndOceanAverageTemperature  \
# 0                         1.571167                       14.867167
# 1                         1.632417                       14.991833
# 2                         1.382917                       15.006500
# 3                         1.355583                       14.955167
# 4                         1.357000                       14.991000
# ..                             ...                             ...
# 161                       0.136583                       15.769500
# 162                       0.145333                       15.802333
# 163                       0.149833                       15.854417
# 164                       0.139000                       15.913000
# 165                       0.141750                       16.058583
#
#      LandAndOceanAverageTemperatureUncertainty
# 0                                     0.308167
# 1                                     0.312083
# 2                                     0.316417
# 3                                     0.283833
# 4                                     0.276417
# ..                                         ...
# 161                                   0.059000
# 162                                   0.061500
# 163                                   0.064667
# 164                                   0.063167
# 165                                   0.060833
#
# [166 rows x 10 columns]

# %%
plt.scatter(data["date"], data["LandAverageTemperature"], s = 50, c = "red")
plt.xlabel("date")
plt.ylabel("temperature")
plt.show()

# %%
p10 = np.poly1d(np.polyfit(x = data["date"], y = data["LandAverageTemperature"], deg = 10))
p8 = np.poly1d(np.polyfit(x = data["date"], y = data["LandAverageTemperature"], deg = 15))
# Out:
# C:\Users\shubh\AppData\Local\Temp\ipykernel_11408\963543253.py:1: RankWarning: Polyfit may be poorly conditioned
#   p10 = np.poly1d(np.polyfit(x = data["date"], y = data["LandAverageTemperature"], deg = 10))
# C:\Users\shubh\AppData\Local\Temp\ipykernel_11408\963543253.py:2: RankWarning: Polyfit may be poorly conditioned
#   p8 = np.poly1d(np.polyfit(x = data["date"], y = data["LandAverageTemperature"], deg = 15))

# %%
xp = np.linspace(1850, 2016, 165)

# %%
plt.plot(data['date'], data['LandAverageTemperature'], 'o', xp, p10(xp), '-', xp, p8(xp), '--')
# Out:
# [<matplotlib.lines.Line2D at 0x1d2f6567770>,
#  <matplotlib.lines.Line2D at 0x1d2f65653a0>,
#  <matplotlib.lines.Line2D at 0x1d2f65675f0>]

# %%
X = np.linspace(1850, 2016, 165)

# %%
plt.plot(X, p10(X))
plt.show()

# %%
lst_ext = []
for i in range(2017, 2037):
    print(i, "\t", p10(i))
    lst_ext.append(p10(i))
# Out:
# 2017 	 9.45861291885376
# 2018 	 9.384958028793335
# 2019 	 9.295432567596436
# 2020 	 9.188537836074829
# 2021 	 9.062691926956177
# 2022 	 8.916219472885132
# 2023 	 8.747350931167603
# 2024 	 8.554208517074585
# 2025 	 8.334829807281494
# 2026 	 8.087125301361084
# 2027 	 7.808905124664307
# 2028 	 7.49786376953125
# 2029 	 7.151575803756714
# 2030 	 6.767489194869995
# 2031 	 6.342931270599365
# 2032 	 5.875094413757324
# 2033 	 5.361035585403442
# 2034 	 4.7976603507995605
# 2035 	 4.181752681732178
# 2036 	 3.509921073913574

# %%
X1 = np.linspace(1850, 2036, 186)
X2 = np.linspace(2016, 2036, 21)
temp = np.linspace(2016, 2036, 11)
fig, (ax1, ax2) = plt.subplots(2)
ax1.plot(X1, p10(X1))
ax2.plot(X2, p10(X2))
plt.xticks(temp)
# Out:
# ([<matplotlib.axis.XTick at 0x1d2f85fbf50>,
#   <matplotlib.axis.XTick at 0x1d2f862da30>,
#   <matplotlib.axis.XTick at 0x1d2f862d0d0>,
#   <matplotlib.axis.XTick at 0x1d2f85eb5f0>,
#   <matplotlib.axis.XTick at 0x1d2f86662a0>,
#   <matplotlib.axis.XTick at 0x1d2f8666bd0>,
#   <matplotlib.axis.XTick at 0x1d2f8667530>,
#   <matplotlib.axis.XTick at 0x1d2f8667e30>,
#   <matplotlib.axis.XTick at 0x1d2f8666f60>,
#   <matplotlib.axis.XTick at 0x1d2f8684530>,
#   <matplotlib.axis.XTick at 0x1d2f8684e60>],
#  [Text(2016.0, 0, '2016'),
#   Text(2018.0, 0, '2018'),
#   Text(2020.0, 0, '2020'),
#   Text(2022.0, 0, '2022'),
#   Text(2024.0, 0, '2024'),
#   Text(2026.0, 0, '2026'),
#   Text(2028.0, 0, '2028'),
#   Text(2030.0, 0, '2030'),
#   Text(2032.0, 0, '2032'),
#   Text(2034.0, 0, '2034'),
#   Text(2036.0, 0, '2036')])
